# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
file_table="data1.csv"
df=pd.read_csv(file_table,  index_col=None)

file_targets="AttrN.csv"
dft=pd.read_csv(file_targets,  index_col=None)
cols=["A1","A2","A3","A4"]
#cols=["A2","A3","A4"]
target_names=dft[cols].iloc[0].values
feature_names=df["PC"].apply(lambda x: "No" if x==0 else "Yes")
X=df[cols]
Y=df["PC"]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X,Y)
cols.append("PC")
df[cols]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A1</th>
#       <th>A2</th>
#       <th>A3</th>
#       <th>A4</th>
#       <th>PC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>0</td>
# ...

# %%
import sklearn.tree as tree
import pydotplus
from sklearn.externals.six import StringIO 
from IPython.display import Image
dot_data = StringIO()
tree.export_graphviz(clf,
 out_file=dot_data,
 feature_names = ["University","Bus Stop","Supermarket","Kiosk"],
 class_names=['YES',"NO"], # the target names.
 filled=True, # Whether to fill in the boxes with colours.
 rounded=True, # Whether to round the corners of the boxes.
 special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
def TestSec2PC(SecN):
    ans="No"
    PC=clf.predict([X.iloc[SecN].values])
    if(PC[0]==1): ans="Yes"
    print("We test Sec="+str(SecN)+" and result is- Do we need pedestrian crossing: "+str(ans))

SecN=0
TestSec2PC(SecN)
SecN=6
TestSec2PC(SecN)
# Out:
# We test Sec=0 and result is- Do we need pedestrian crossing: No
# We test Sec=6 and result is- Do we need pedestrian crossing: Yes

# %%
X.iloc[0].values
# Out:
# array([1, 0, 0, 0])

# %%
feature_names
# Out:
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4     No
# 5     No
# 6    Yes
# 7     No
# 8     No
# 9     No
# Name: PC, dtype: object
